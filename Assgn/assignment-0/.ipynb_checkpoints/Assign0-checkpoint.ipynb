# %% [markdown]
# ### Name: Aryan Jain
# ### Roll Num : 2019101056

# %%
# Problem 1

# breaking a video into it's constituent images and saving it in images folder (also showing them on the screen)
import cv2
import matplotlib.pyplot as plt
import os

vidcap = cv2.VideoCapture('input.mp4')

def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        cv2.imwrite("./images/image"+str(count)+".jpg", image)     # save frame as JPG file
        # displaying the images         
        plt.imshow(image)
        plt.title('frame {}'.format(count))
        plt.xticks([]), plt.yticks([]) 
        plt.show()
        
    return hasFrames

sec = 0
frameRate = 0.5 #it will capture image in each 0.5 second
count=1
success = getFrame(sec)
os.mkdir('images')  # creating folder images, where we will store all frames of the video.

# the loop will run till the time the function is returning the frames.
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)   #rounding to 2 decimal places
    success = getFrame(sec)

# %%
# merging the frames in images folder to a video named output
import cv2
import numpy as np
import os
from os.path import isfile, join

# name of the directory where video frames are there 
pathIn= './images/'

# name of the output video file
pathOut = 'output.avi'

# setting frame rate (frames per second)
fps = 2

files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]#for sorting the file names properly
files.sort(key = lambda x: x[5:-4])
files.sort()

frame_array = []
for i in range(len(files)):
    filename=pathIn + files[i]
    #reading each files
    img = cv2.imread(filename)
    height, width, layers = img.shape
    size = (width,height)
    
    #inserting the frames into an image array
    frame_array.append(img)
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
    for i in range(len(frame_array)):
        # writing to a image array
        out.write(frame_array[i])
    out.release()

# %%
# # Problem 2
# import cv2

# # Opens the inbuilt camera of laptop to capture video.
# cap = cv2.VideoCapture(0)
# i = 0

# while(cap.isOpened()):
#     ret, frame = cap.read()

#     # This condition prevents from infinite looping
#     # incase video ends.
#     if ret == False:
#         print('Fuck')
#         break

#     # Save Frame by Frame into disk using imwrite method
#     # displaying the images         
#     plt.imshow(frame)
#     plt.title('frame {}'.format(i+1))
#     plt.xticks([]), plt.yticks([]) 
#     plt.show()
#     cv2.imwrite('Frame'+str(i)+'.jpg', frame)
#     i += 1

# cap.release()
# cv2.destroyAllWindows()

import cv2
cap = cv2.VideoCapture(0)
while True:

    ret, frame = cap.read()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@526.432] global /io/opencv/modules/videoio/src/cap_v4l.cpp (889) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_19653/2195589006.py in <module>
#      32
#      33     ret, frame = cap.read()
# ---> 34     cv2.imshow('frame',frame)
#      35     if cv2.waitKey(1) & 0xFF == ord('q'):
#      36         break
#
# error: OpenCV(4.5.5) /io/opencv/modules/highgui/src/window.cpp:1000: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
